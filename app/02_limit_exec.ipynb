# %%
from lib.helders import *
from lib.data_processing import *
from params import PARAMS

SYMBOL = 'SOLUSDC'

# Load data
blocks = load_from_pickle(PARAMS['base_dir'], SYMBOL)
print(f'Loaded {len(blocks)} blocks')
# Out:
# Loaded 2 blocks

# %%
import random
from lib.limit_exec import *

# Random test
test_volume_usd = 1_000_000
max_time_ms = 600_000

random_test(test_volume_usd, max_time_ms, *random.choice(blocks))
# Out:
# Current price: 143425, random shift: 7, side: 1, price: 143418
# Real price: 143.418
# Base volume: 6972.6255
# Test volume units: 697262.0000 for volume step 0.01
# Stopped at index: 56202496 (1140 trades executed)
# Trace shape: (576,)
# Volume left: 431054 (61.82095109155525%)
# Drift: 0.03486312736197261%
# Execution time: 97.1510 seconds
